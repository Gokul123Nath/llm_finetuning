# %%
# %%capture
# !mamba install cudatoolkit xformers bitsandbytes pytorch pytorch-cuda=11.8 \
    -c pytorch -c nvidia -c xformers -c conda-forge -y
# !pip install "unsloth[kaggle] @ git+https://github.com/unslothai/unsloth.git"

# %%
from unsloth import FastLlamaModel
import torch
max_seq_length = 2048
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

model, tokenizer = FastLlamaModel.from_pretrained(
    model_name = "unsloth/llama-2-7b",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# /opt/conda/lib/python3.10/site-packages/unsloth/__init__.py:38: UserWarning: Unsloth: 'CUDA_VISIBLE_DEVICES' is not set. We shall set it ourselves.
#   warnings.warn("Unsloth: 'CUDA_VISIBLE_DEVICES' is not set. We shall set it ourselves.")
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/unsloth/__init__.py:65: UserWarning: CUDA is not linked properly.
# We shall run `ldconfig /usr/lib64-nvidia` to try to fix it.
#   warnings.warn(
# ==((====))==  Unsloth: Fast Llama patching release 23.11
#    \\   /|    GPU: Tesla T4. Max memory: 14.756 GB
# O^O/ \_/ \    CUDA compute capability = 7.5
# \        /    Pytorch version: 2.1.0. CUDA Toolkit = 11.8
#  "-____-"     bfloat16 support = FALSE
# Downloading config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Downloading (…)of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# Downloading (…)of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading generation_config.json:   0%|          | 0.00/183 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]

# %%
model = FastLlamaModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Currently only supports dropout = 0
    bias = "none",    # Currently only supports bias = "none"
    use_gradient_checkpointing = True,
    random_state = 3407,
    max_seq_length = max_seq_length,
)

# %%
from datasets import load_dataset
url = "https://huggingface.co/datasets/laion/OIG/resolve/main/unified_chip2.jsonl"
dataset = load_dataset("json", data_files = {"train" : url}, split = "train")
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-22c7a0a286c94ba8/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/95.6M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-22c7a0a286c94ba8/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

trainer = SFTTrainer(
    model = model,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 10,
        max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",
    ),
)
trainer.train()
# Out:
# /opt/conda/lib/python3.10/site-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(
#   0%|          | 0/211 [00:00<?, ?ba/s]
# You are using 8-bit optimizers with a version of `bitsandbytes` < 0.41.1. It is recommended to update your version as a major bug has been fixed in 8-bit optimizers.
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 04:34, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.669100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.558900</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.616500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.712200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.990500</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.947900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.684600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.488900</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.475700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.733000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.727400</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.420500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.441600</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.008300</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.169400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.474100</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.780900</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.403300</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.446900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.543400</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.398300</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.117000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.163600</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.096100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.069700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.311400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.115900</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.644600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.416700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.176400</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.060200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.608400</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.156000</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.461200</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.095400</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.452900</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.176500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.683500</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.355500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.576100</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.271000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.374200</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.271500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.979000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.110300</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.471600</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.310800</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.257700</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.115000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.202000</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.897400</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.303400</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.873900</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.457200</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.272500</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.484500</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.296400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.717300</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.127300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.375100</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=60, training_loss=1.3766083866357803, metrics={'train_runtime': 285.384, 'train_samples_per_second': 1.682, 'train_steps_per_second': 0.21, 'total_flos': 2418640886218752.0, 'train_loss': 1.3766083866357803, 'epoch': 0.0})
